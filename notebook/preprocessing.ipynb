# %%
import pandas as pd
from pymongo import MongoClient

# %%
# Se connecter à MongoDB
client = MongoClient('mongodb://localhost:27017/')

# %%
db = client['velibe']

# %%
# Sélectionner la collection
collection = db['collection_velibe']

# %%
# Récupérer toutes les données de la collection sous forme de liste de dictionnaires
data = list(collection.find())

# %%
# Afficher les données avec Pandas
df = pd.DataFrame(data)
df.head(10)
# Out:
#                         _id stationcode                                 name  \
# 0  6643d9f8c469d48b125f6db3        9020                   Toudouze - Clauzel
# 1  6643d9f8c469d48b125f6db4       14111          Cassini - Denfert-Rochereau
# 2  6643d9f8c469d48b125f6db5       14014             Jourdan - Stade Charléty
# 3  6643d9f8c469d48b125f6db6       32017                            Basilique
# 4  6643d9f8c469d48b125f6db7       11104  Charonne - Robert et Sonia Delaunay
# 5  6643d9f8c469d48b125f6db8        8026             Messine - Place Du Pérou
# 6  6643d9f8c469d48b125f6db9       13007                   Le Brun - Gobelins
# 7  6643d9f8c469d48b125f6dba        7002                      Vaneau - Sèvres
# 8  6643d9f8c469d48b125f6dbb        5110                     Lacépède - Monge
# 9  6643d9f8c469d48b125f6dbc        6108          Saint-Romain - Cherche-Midi
#
#   is_installed  capacity  numdocksavailable  numbikesavailable  mechanical  \
# 0          OUI        21                 16                  5           3
# 1          OUI        25                 23                  2           1
# 2          OUI        60                 51                  5           2
# 3          OUI        22                  5                 13           9
# 4          OUI        20                 11                  9           7
# 5          OUI        12                 11                  0           0
# 6          OUI        48                 27                 21          17
# 7          OUI        35                 12                 21          19
# 8          OUI        23                 20                  3           0
# 9          OUI        17                 17                  0           0
#
#    ebike is_renting is_returning                    duedate  \
# 0      2        OUI          OUI  2024-05-14T20:45:33+00:00
# 1      1        OUI          OUI  2024-05-14T20:52:24+00:00
# 2      3        OUI          OUI  2024-05-14T20:52:18+00:00
# 3      4        OUI          OUI  2024-05-14T20:52:12+00:00
# 4      2        OUI          OUI  2024-05-14T20:49:47+00:00
# 5      0        OUI          OUI  2024-05-14T20:50:01+00:00
# 6      4        OUI          OUI  2024-05-14T20:51:23+00:00
# 7      2        OUI          OUI  2024-05-14T20:50:28+00:00
# 8      3        OUI          OUI  2024-05-14T20:48:16+00:00
# 9      0        OUI          OUI  2024-05-14T20:44:59+00:00
#
#                                      coordonnees_geo  \
# 0  {'lon': 2.3373600840568547, 'lat': 48.87929591...
# 1   {'lon': 2.3360354080796, 'lat': 48.837525839067}
# 2   {'lon': 2.3433353751898, 'lat': 48.819428333369}
# 3  {'lon': 2.3588666820200914, 'lat': 48.93626891...
# 4   {'lon': 2.3925706744194, 'lat': 48.855907555969}
# 5  {'lon': 2.315508019010038, 'lat': 48.875448033...
# 6   {'lon': 2.3534681351338, 'lat': 48.835092787824}
# 7   {'lon': 2.3204218259346, 'lat': 48.848563233059}
# 8  {'lon': 2.3519663885235786, 'lat': 48.84389286...
# 9  {'lon': 2.321374788880348, 'lat': 48.847081590...
#
#   nom_arrondissement_communes code_insee_commune
# 0                       Paris               None
# 1                       Paris               None
# 2                       Paris               None
# 3                 Saint-Denis               None
# 4                       Paris               None
# 5                       Paris               None
# 6                       Paris               None
# 7                       Paris               None
# 8                       Paris               None
# 9                       Paris               None

# %% [markdown]
# EDA

# %%
df .describe()
# Out:
#           capacity  numdocksavailable  numbikesavailable   mechanical  \
# count  3260.000000        3260.000000        3260.000000  3260.000000
# mean     30.887117          17.750613          12.017178     7.159509
# std      12.255093          14.584290          10.824509     9.286928
# min       0.000000           0.000000           0.000000     0.000000
# 25%      22.000000           7.000000           3.000000     1.000000
# 50%      29.000000          15.000000           9.000000     2.000000
# 75%      37.000000          24.000000          20.000000    10.000000
# max      64.000000          60.000000          49.000000    48.000000
#
#              ebike
# count  3260.000000
# mean      4.857669
# std       5.325259
# min       0.000000
# 25%       1.000000
# 50%       3.000000
# 75%       8.000000
# max      24.000000

# %%
taille=len(df)

# %%
print(taille)
# Out:
# 3260
